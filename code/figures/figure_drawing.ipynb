# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, MiniBatchKMeans, SpectralClustering

# %%
data = pd.read_csv('../evaluation_results/tfidf_params_final.csv')
print('number of items = ', len(data))
print('keys = ', data.keys())
print('-------vectorizers--------')
print(data['vectorizer'].unique())
print('-------similarity metrics--------')
print(data['similarity_metric'].unique())
print('-------languages-----------')
print(data['language'].unique())
# Out:
# number of items =  582
# keys =  Index(['vectorizer', 'similarity_metric', 'min_df_param', 'max_df_param',
#        'language', 'langfilter', 'accuracy (%)',
#        'accuracy (average relevancy > 0) (%)', 'ndcg', 'ndcg (full rank)'],
#       dtype='object')
# -------vectorizers--------
# ['tfidf']
# -------similarity metrics--------
# ['cosine' 'linear' 'rbf']
# -------languages-----------
# ['javascript' 'java' 'python' 'go']

# %%
data.head(10)
# Out:
#   vectorizer similarity_metric  min_df_param max_df_param    language  \
# 0      tfidf            cosine          0.30          0.9  javascript
# 1      tfidf            cosine         50.00          1.0        java
# 2      tfidf            cosine          0.00          0.8      python
# 3      tfidf            cosine          0.60          0.8        java
# 4      tfidf            cosine          0.60          1.0      python
# 5      tfidf            cosine        700.00          0.9        java
# 6      tfidf            cosine          0.05          0.7          go
# 7      tfidf            cosine        900.00          1.0          go
# 8      tfidf            cosine          0.50          0.9  javascript
# 9      tfidf            cosine          0.01          0.4          go
#
#    langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 0       False      0.000000                              0.000000  0.000000
# 1        True     24.477245                             23.112128  0.202992
# 2       False     22.143579                             23.208191  0.270402
# 3        True      0.000000                              0.000000  0.000000
# 4        True      0.000000                              0.000000  0.000000
# 5        True     19.557196                             19.450801  0.177812
# 6        True      0.000000                              0.000000  0.000000
# 7        True     13.855422                             13.461538  0.103880
# 8       False      0.000000                              0.000000  0.000000
# 9       False      2.409639                              1.923077  0.013067
#
#    ndcg (full rank)
# 0          0.000000
# 1          0.101007
# 2          0.146241
# 3          0.000000
# 4          0.000000
# 5          0.084971
# 6          0.000000
# 7          0.028020
# 8          0.000000
# 9          0.002438

# %%
py_yes_cosine = {'language': 'python', 'langfilter': True, 'similarity_metric':'cosine'}
py_yes_rbf = {'language': 'python', 'langfilter': True, 'similarity_metric':'rb'}
py_yes_linear = {'language': 'python', 'langfilter': True, 'similarity_metric':'linear'}
py_no_cosine = {'language': 'python', 'langfilter': False, 'similarity_metric':'cosine'}
py_no_rbf = {'language': 'python', 'langfilter': False, 'similarity_metric':'rb'}
py_no_linear = {'language': 'python', 'langfilter': False, 'similarity_metric':'linear'}

def build_filter(data, kf: dict):
    if (len(kf.keys()) < 1):
        raise ValueError()
        
    tempk, tempv = list(kf.keys())[0], list(kf.values())[0]
    base = (data[tempk] == tempv)
    for k,v in kf.items():
        base = base & (data[k] == v)
    return base

# %%
accuracy_filter = (data['accuracy (%)'] > 0.000) & \
                (data['accuracy (average relevancy > 0) (%)'] > 0.000) & \
                (data['ndcg'] > 0.000) & \
                (data['ndcg (full rank)'])

# %% [markdown]
# # Understanding Data

# %%
benchmark = pd.read_csv('../evaluation_results/reference_benchmarks.csv')
benchmark.sort_values(by=['language'])
# Out:
#   vectorizer similarity_metric min_df_param max_df_param    language  \
# 1    selfatt              None         None         None          go
# 5       nbow              None         None         None          go
# 2    selfatt              None         None         None        java
# 6       nbow              None         None         None        java
# 3    selfatt              None         None         None  javascript
# 7       nbow              None         None         None  javascript
# 0    selfatt              None         None         None      python
# 4       nbow              None         None         None      python
#
#    langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)   ndcg  \
# 1       False          6.63                                  8.65  0.101
# 5       False         15.06                                 21.15  0.221
# 2       False         11.19                                 14.42  0.173
# 6       False         21.65                                 26.54  0.257
# 3       False          9.40                                 13.25  0.153
# 7       False         21.32                                 25.30  0.232
# 0       False         17.09                                 18.32  0.239
# 4       False         24.77                                 26.28  0.306
#
#    ndcg (full rank)
# 1             0.058
# 5             0.146
# 2             0.115
# 6             0.201
# 3             0.060
# 7             0.152
# 0             0.167
# 4             0.233

# %%
full_res = data[build_filter(data, {'language': 'python'}) & accuracy_filter]
full_res.sort_values(by=['accuracy (%)', 'ndcg', 'ndcg (full rank)'], ascending=False).head(25)
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param language  \
# 239      tfidf            cosine          50.0          1.0   python
# 231      tfidf            cosine          50.0          0.9   python
# 515      tfidf            cosine          50.0          0.8   python
# 37       tfidf            linear         100.0          1.0   python
# 65       tfidf            cosine         100.0         None   python
# 108      tfidf               rbf         100.0          1.0   python
# 232      tfidf            cosine         100.0          1.0   python
# 240      tfidf            cosine         100.0          0.8   python
# 511      tfidf            cosine         100.0          0.9   python
# 351      tfidf            cosine         100.0         None   python
# 406      tfidf            linear         100.0          1.0   python
# 409      tfidf            cosine         200.0          1.0   python
# 182      tfidf            cosine         200.0          0.8   python
# 424      tfidf            cosine         200.0          0.9   python
# 20       tfidf            cosine           0.0          0.8   python
# 88       tfidf            cosine           0.0          1.0   python
# 486      tfidf            cosine           0.0          1.0   python
# 2        tfidf            cosine           0.0          0.8   python
# 235      tfidf            cosine           0.0          0.7   python
# 238      tfidf            cosine           0.0          0.9   python
# 506      tfidf            cosine           0.0          0.7   python
# 513      tfidf            cosine           0.0          0.9   python
# 473      tfidf            cosine           0.0          0.4   python
# 467      tfidf            cosine           0.0          0.6   python
# 565      tfidf            cosine           0.0          0.5   python
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 239        True     24.469161                             25.597270  0.290676
# 231        True     24.469161                             25.597270  0.290676
# 515        True     24.469161                             25.597270  0.290676
# 37        False     24.469161                             25.483504  0.284858
# 65        False     24.469161                             25.483504  0.284858
# 108       False     24.469161                             25.483504  0.284858
# 232        True     24.469161                             25.483504  0.284858
# 240        True     24.368049                             25.369738  0.282860
# 511        True     24.368049                             25.369738  0.282860
# 351        True     24.266936                             25.369738  0.283487
# 406        True     24.266936                             25.369738  0.283487
# 409        True     23.255814                             24.232082  0.268843
# 182        True     23.255814                             24.232082  0.268843
# 424        True     23.255814                             24.232082  0.268843
# 20         True     22.143579                             23.208191  0.272037
# 88         True     22.143579                             23.208191  0.272037
# 486       False     22.143579                             23.208191  0.270402
# 2         False     22.143579                             23.208191  0.270402
# 235       False     22.143579                             23.208191  0.270402
# 238        True     22.143579                             23.208191  0.270402
# 506        True     22.143579                             23.208191  0.270402
# 513       False     22.143579                             23.208191  0.270402
# 473       False     22.143579                             23.208191  0.269892
# 467        True     22.143579                             23.208191  0.269610
# 565        True     22.042467                             23.094425  0.269950
#
#      ndcg (full rank)
# 239          0.146960
# 231          0.146694
# 515          0.146694
# 37           0.146937
# 65           0.146937
# 108          0.146937
# 232          0.146937
# 240          0.146287
# 511          0.146287
# 351          0.146810
# 406          0.146810
# 409          0.136304
# 182          0.136104
# 424          0.136104
# 20           0.146187
# 88           0.146187
# 486          0.146279
# 2            0.146241
# 235          0.146241
# 238          0.146241
# 506          0.146241
# 513          0.146241
# 473          0.144821
# 467          0.145189
# 565          0.143971

# %%
full_res = data[build_filter(data, {'language': 'go'})]
full_res.sort_values(by=['accuracy (%)', 'ndcg', 'ndcg (full rank)'], ascending=False).head(25)
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param language  \
# 51       tfidf            cosine           0.0          1.0       go
# 265      tfidf            cosine           0.0          0.4       go
# 121      tfidf            cosine           0.0          0.4       go
# 327      tfidf            cosine           0.0          0.8       go
# 536      tfidf            cosine           0.0          0.6       go
# 120      tfidf            cosine           0.0          0.5       go
# 543      tfidf            cosine           0.0          0.5       go
# 85       tfidf            cosine           0.0          1.0       go
# 96       tfidf            cosine           0.0          0.9       go
# 434      tfidf            cosine           0.0          0.9       go
# 184      tfidf            cosine           0.0          0.6       go
# 335      tfidf            cosine           0.0          0.7       go
# 433      tfidf            cosine           0.0          0.7       go
# 447      tfidf            cosine           0.0          0.8       go
# 98       tfidf            cosine         100.0         None       go
# 193      tfidf            cosine         100.0          1.0       go
# 529      tfidf            cosine          50.0          1.0       go
# 431      tfidf            cosine          50.0          0.8       go
# 25       tfidf            cosine          50.0          0.9       go
# 374      tfidf            cosine         100.0          0.9       go
# 491      tfidf            cosine         100.0          0.8       go
# 278      tfidf            cosine         100.0         None       go
# 465      tfidf            cosine         200.0          0.9       go
# 569      tfidf            cosine         200.0          1.0       go
# 461      tfidf            cosine         200.0          0.8       go
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 51        False     24.096386                             25.961538  0.259306
# 265        True     24.096386                             25.961538  0.259306
# 121       False     24.096386                             25.961538  0.259306
# 327        True     24.096386                             25.961538  0.259306
# 536        True     24.096386                             25.961538  0.259306
# 120       False     24.096386                             25.961538  0.259306
# 543        True     24.096386                             25.961538  0.259306
# 85         True     24.096386                             25.961538  0.259306
# 96        False     24.096386                             25.961538  0.259306
# 434        True     24.096386                             25.961538  0.259306
# 184       False     24.096386                             25.961538  0.259306
# 335       False     24.096386                             25.961538  0.259306
# 433        True     24.096386                             25.961538  0.259306
# 447       False     24.096386                             25.961538  0.259306
# 98        False     20.481928                             20.192308  0.187402
# 193        True     20.481928                             20.192308  0.187402
# 529        True     19.879518                             21.153846  0.216553
# 431        True     19.879518                             21.153846  0.216553
# 25         True     19.879518                             21.153846  0.216553
# 374        True     19.879518                             19.230769  0.181713
# 491        True     19.879518                             19.230769  0.181713
# 278        True     19.879518                             19.230769  0.181713
# 465        True     18.674699                             17.307692  0.169743
# 569        True     18.674699                             17.307692  0.169743
# 461        True     18.674699                             17.307692  0.169743
#
#      ndcg (full rank)
# 51           0.071824
# 265          0.071453
# 121          0.071440
# 327          0.071378
# 536          0.071378
# 120          0.071377
# 543          0.071377
# 85           0.071370
# 96           0.071360
# 434          0.071360
# 184          0.071346
# 335          0.071346
# 433          0.071346
# 447          0.071346
# 98           0.051599
# 193          0.051599
# 529          0.061490
# 431          0.061487
# 25           0.061391
# 374          0.050247
# 491          0.045725
# 278          0.045725
# 465          0.039886
# 569          0.039868
# 461          0.039383

# %%
full_res = data[build_filter(data, {'language': 'java'})]
full_res.sort_values(by=['accuracy (%)', 'ndcg', 'ndcg (full rank)'], ascending=False).head(25)
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param language  \
# 53       tfidf            cosine         100.0         None     java
# 69       tfidf            cosine         100.0          0.8     java
# 336      tfidf            cosine         100.0          0.9     java
# 509      tfidf            cosine         100.0          1.0     java
# 1        tfidf            cosine          50.0          1.0     java
# 12       tfidf            cosine          50.0          0.9     java
# 247      tfidf            cosine          50.0          0.8     java
# 18       tfidf            cosine         100.0         None     java
# 45       tfidf            cosine           0.0          0.9     java
# 97       tfidf            cosine           0.0          0.8     java
# 214      tfidf            cosine           0.0          0.9     java
# 267      tfidf            cosine           0.0          1.0     java
# 103      tfidf            cosine           0.0          1.0     java
# 479      tfidf            cosine           0.0          0.8     java
# 122      tfidf            cosine           0.0          0.7     java
# 218      tfidf            cosine           0.0          0.7     java
# 377      tfidf            cosine           0.0          0.6     java
# 378      tfidf            cosine           0.0          0.4     java
# 248      tfidf            cosine           0.0          0.6     java
# 262      tfidf            cosine           0.0          0.5     java
# 526      tfidf            cosine           0.0          0.5     java
# 297      tfidf            cosine           0.0          0.4     java
# 314      tfidf            cosine         200.0          0.9     java
# 358      tfidf            cosine         200.0          1.0     java
# 498      tfidf            cosine         200.0          0.8     java
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 53        False     24.723247                             23.569794  0.224640
# 69         True     24.723247                             23.569794  0.224640
# 336        True     24.723247                             23.569794  0.224640
# 509        True     24.723247                             23.569794  0.224640
# 1          True     24.477245                             23.112128  0.202992
# 12         True     24.477245                             23.112128  0.202992
# 247        True     24.477245                             23.112128  0.202992
# 18         True     24.354244                             23.112128  0.219021
# 45         True     22.878229                             23.798627  0.220600
# 97        False     22.878229                             23.798627  0.220600
# 214       False     22.878229                             23.798627  0.220600
# 267       False     22.878229                             23.798627  0.220600
# 103        True     22.878229                             23.798627  0.220600
# 479        True     22.878229                             23.798627  0.220600
# 122        True     22.878229                             23.569794  0.219332
# 218       False     22.878229                             23.569794  0.219332
# 377       False     22.878229                             23.569794  0.219332
# 378       False     22.878229                             23.569794  0.216744
# 248        True     22.755228                             23.569794  0.217780
# 262        True     22.509225                             23.112128  0.214461
# 526       False     22.509225                             23.112128  0.214461
# 297        True     22.509225                             23.340961  0.212546
# 314        True     22.263223                             20.594966  0.201596
# 358        True     22.263223                             20.594966  0.201596
# 498        True     22.263223                             20.594966  0.201596
#
#      ndcg (full rank)
# 53           0.098874
# 69           0.098874
# 336          0.098874
# 509          0.098874
# 1            0.101007
# 12           0.101007
# 247          0.101007
# 18           0.097968
# 45           0.102095
# 97           0.102095
# 214          0.102095
# 267          0.102095
# 103          0.101993
# 479          0.101993
# 122          0.101750
# 218          0.101750
# 377          0.101716
# 378          0.101101
# 248          0.101049
# 262          0.100502
# 526          0.100502
# 297          0.100414
# 314          0.099002
# 358          0.099002
# 498          0.099002

# %%
full_res = data[build_filter(data, {'language': 'javascript'})]
full_res.sort_values(by=['accuracy (%)', 'ndcg', 'ndcg (full rank)'], ascending=False).head(25)
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param    language  \
# 326      tfidf            cosine          50.0          1.0  javascript
# 164      tfidf            cosine          50.0          0.8  javascript
# 386      tfidf            cosine          50.0          0.9  javascript
# 294      tfidf            cosine         100.0         None  javascript
# 534      tfidf            cosine         100.0          1.0  javascript
# 341      tfidf            cosine         100.0          0.9  javascript
# 417      tfidf            cosine         100.0          0.8  javascript
# 54       tfidf            cosine         100.0         None  javascript
# 204      tfidf            cosine         200.0          1.0  javascript
# 145      tfidf            cosine         200.0          0.8  javascript
# 250      tfidf            cosine         200.0          0.9  javascript
# 567      tfidf            cosine           0.0          1.0  javascript
# 160      tfidf            cosine           0.0          0.9  javascript
# 268      tfidf            cosine           0.0          0.7  javascript
# 330      tfidf            cosine           0.0          0.9  javascript
# 352      tfidf            cosine           0.0          0.7  javascript
# 492      tfidf            cosine           0.0          0.8  javascript
# 61       tfidf            cosine           0.0          1.0  javascript
# 328      tfidf            cosine           0.0          0.8  javascript
# 35       tfidf            cosine           0.0          0.5  javascript
# 291      tfidf            cosine           0.0          0.5  javascript
# 331      tfidf            cosine           0.0          0.4  javascript
# 83       tfidf            cosine           0.0          0.6  javascript
# 404      tfidf            cosine           0.0          0.6  javascript
# 196      tfidf            cosine           0.0          0.4  javascript
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 326        True     22.884013                             25.903614  0.219616
# 164        True     22.884013                             25.903614  0.219616
# 386        True     22.884013                             25.903614  0.219616
# 294       False     22.884013                             25.903614  0.210216
# 534        True     22.884013                             25.903614  0.210216
# 341        True     22.570533                             25.903614  0.210216
# 417        True     22.570533                             25.903614  0.210216
# 54         True     22.570533                             25.903614  0.210216
# 204        True     22.570533                             24.698795  0.189697
# 145        True     22.257053                             24.698795  0.189697
# 250        True     22.257053                             24.698795  0.189697
# 567       False     21.630094                             23.493976  0.206368
# 160        True     21.630094                             23.493976  0.206368
# 268       False     21.630094                             23.493976  0.206368
# 330       False     21.630094                             23.493976  0.206368
# 352        True     21.630094                             23.493976  0.206368
# 492       False     21.630094                             23.493976  0.206368
# 61         True     21.630094                             23.493976  0.206368
# 328        True     21.630094                             23.493976  0.206368
# 35        False     21.630094                             23.493976  0.206368
# 291        True     21.630094                             23.493976  0.206368
# 331       False     21.630094                             23.493976  0.206368
# 83        False     21.316614                             22.891566  0.204927
# 404        True     21.316614                             22.891566  0.204927
# 196        True     21.316614                             22.891566  0.204927
#
#      ndcg (full rank)
# 326          0.096494
# 164          0.096331
# 386          0.096331
# 294          0.095089
# 534          0.095089
# 341          0.095020
# 417          0.095020
# 54           0.093593
# 204          0.081804
# 145          0.081783
# 250          0.081783
# 567          0.091322
# 160          0.091047
# 268          0.091047
# 330          0.091047
# 352          0.091047
# 492          0.091047
# 61           0.090916
# 328          0.090916
# 35           0.089562
# 291          0.089562
# 331          0.089562
# 83           0.090139
# 404          0.090000
# 196          0.089127

# %%
print('{},{},{},{},{}'.format('language','filter','similarity', 'nonzero', 'totaltrials'))
for l in ['python', 'go', 'javascript', 'java']:
    for f in [True, False]:
        for sm in ['cosine', 'rb', 'linear']:
            temp = {'language': l, 'langfilter': f, 'similarity_metric': sm }
            temp_filter = build_filter(data, temp)
            total_count = len(data[temp_filter])
            if total_count < 2:
                continue
            non0tfidf = len(data[temp_filter & accuracy_filter])
            print('{},{},{},{},{}'.format(l, f, sm, non0tfidf, total_count))

# %% [markdown]
# # Benchmarks By Similarity

# %%
data[data['similarity_metric'] == 'linear']
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param language  \
# 37       tfidf            linear         100.0          1.0   python
# 406      tfidf            linear         100.0          1.0   python
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 37        False     24.469161                             25.483504  0.284858
# 406        True     24.266936                             25.369738  0.283487
#
#      ndcg (full rank)
# 37           0.146937
# 406          0.146810

# %%
data[data['similarity_metric'] == 'rbf']
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param language  \
# 108      tfidf               rbf         100.0          1.0   python
# 559      tfidf               rbf         100.0          1.0   python
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 108       False     24.469161                             25.483504  0.284858
# 559        True     15.874621                             16.837315  0.198271
#
#      ndcg (full rank)
# 108          0.146937
# 559          0.115572

# %%
data[(data['similarity_metric'] == 'cosine') & \
     (data['min_df_param'] == 100.0) & \
     (data['language'] == 'python')].sort_values(by=['max_df_param'])
# Out:
#     vectorizer similarity_metric  min_df_param max_df_param language  \
# 240      tfidf            cosine         100.0          0.8   python
# 511      tfidf            cosine         100.0          0.9   python
# 232      tfidf            cosine         100.0          1.0   python
# 65       tfidf            cosine         100.0         None   python
# 351      tfidf            cosine         100.0         None   python
#
#      langfilter  accuracy (%)  accuracy (average relevancy > 0) (%)      ndcg  \
# 240        True     24.368049                             25.369738  0.282860
# 511        True     24.368049                             25.369738  0.282860
# 232        True     24.469161                             25.483504  0.284858
# 65        False     24.469161                             25.483504  0.284858
# 351        True     24.266936                             25.369738  0.283487
#
#      ndcg (full rank)
# 240          0.146287
# 511          0.146287
# 232          0.146937
# 65           0.146937
# 351          0.146810

# %% [markdown]
# # Other Plots

# %%
data_index = {
    'python': data[build_filter(data, {'language': 'python', 'similarity_metric':'cosine'})],
    'go': data[build_filter(data, {'language': 'go', 'similarity_metric':'cosine'})],
    'java': data[build_filter(data, {'language': 'java', 'similarity_metric':'cosine'})],
    'javascript':  data[build_filter(data, {'language': 'javascript', 'similarity_metric':'cosine'})],
}
col_ind = {
    'python': 'green',
    'go': 'blue',
    'java': 'red',
    'javascript': 'black'
}

# %% [markdown]
# # Fix min_df_param = 0, yes language filter

# %%
plt.figure()
plt.xlabel('TF-IDF max df value')
plt.ylabel('ndcg')
for l in ['python', 'go', 'java', 'javascript']:
    tdata = data_index[l]
    tfilt = (tdata['langfilter'] == True) & (tdata['min_df_param'] <= 0.00)
    tplt = tdata[tfilt]
        
    plot_indices = np.argsort(tplt['max_df_param'])
    plt.plot(tplt.iloc[plot_indices]['max_df_param'], tplt.iloc[plot_indices]['ndcg'], color = col_ind[l])

plt.show()

# %% [markdown]
# # Fix min_df_param = 0, yes language filter, accuracy

# %%
for yaxis in ['accuracy (%)', 'accuracy (average relevancy > 0) (%)', 'ndcg', 'ndcg (full rank)']:
    for z in [True, False]:
        plt.figure()
        plt.xlabel('max_df parameter') 
        plt.ylabel(yaxis.replace('(%)', ''))
        syntax_filtered = ', syntax_filtered' if z else ''
        plt.title('TF-IDF Cosine Similarity (min_df=0.0{})'.format(syntax_filtered))
        
        patches = [mpatches.Patch(color=col_ind[lan] ,label=lan) for lan in ['python', 'go', 'java', 'javascript']]
        plt.legend(handles=patches)
        for l in ['python', 'go', 'java', 'javascript']:   
            tdata = data_index[l]
            tfilt = (tdata['langfilter'] == z) & (tdata['min_df_param'] <= 0.00)
            tplt = tdata[tfilt]

            plot_indices = np.argsort(tplt['max_df_param'])
            plt.plot(tplt.iloc[plot_indices]['max_df_param'], 
                     tplt.iloc[plot_indices]['ndcg'], 
                     color = col_ind[l])
        print('tfidf_cosine_sim_min_df=0.0_{}_{}.png'.format(syntax_filtered[2:], 
                                                            yaxis.replace(' (%)', '').replace('(average relevancy > 0)', '')))
        plt.savefig('tfidf_cosine_sim_min_df=0.0_{}_{}.png'.format(syntax_filtered[2:], 
                                                            yaxis.replace(' (%)', '').replace('(average relevancy > 0)', '')))
        plt.show()
# Out:
# tfidf_cosine_sim_min_df=0.0_syntax_filtered_accuracy .png
# tfidf_cosine_sim_min_df=0.0__accuracy .png
# tfidf_cosine_sim_min_df=0.0_syntax_filtered_accuracy  .png
# tfidf_cosine_sim_min_df=0.0__accuracy  .png
# tfidf_cosine_sim_min_df=0.0_syntax_filtered_ndcg.png
# tfidf_cosine_sim_min_df=0.0__ndcg.png
# tfidf_cosine_sim_min_df=0.0_syntax_filtered_ndcg (full rank).png
# tfidf_cosine_sim_min_df=0.0__ndcg (full rank).png
